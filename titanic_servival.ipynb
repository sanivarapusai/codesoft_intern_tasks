# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

# %%
df=pd.read_csv("/content/drive/MyDrive/Machine_learning/Titanic-Dataset.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.sample(10)
# Out:
#      PassengerId  Survived  Pclass  \
# 537          538         1       1
# 383          384         1       1
# 345          346         1       2
# 887          888         1       1
# 72            73         0       2
# 493          494         0       1
# 776          777         0       3
# 715          716         0       3
# 586          587         0       2
# 124          125         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 537                                LeRoy, Miss. Bertha  female  30.0      0
# 383  Holverson, Mrs. Alexander Oskar (Mary Aline To...  female  35.0      1
# 345                      Brown, Miss. Amelia "Mildred"  female  24.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 72                                Hood, Mr. Ambrose Jr    male  21.0      0
# 493                            Artagaveytia, Mr. Ramon    male  71.0      0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.loc[df['Age'] > 100].count()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
df.loc[df["Age"]<0].count()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
df['Age'].interpolate(method='linear',inplace=True)

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.fillna(method='ffill',inplace=True)

# %%
df.fillna(method='bfill',inplace=True)

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
sns.barplot(x='Sex',y='Survived',data=df)
# Out:
# <Axes: xlabel='Sex', ylabel='Survived'>

# %%
sns.barplot(x="Sex",y="Age",hue="Survived", data=df)
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
y=df["Survived"]

# %%
x=df.drop(["Survived","Name"],axis=1)

# %%
x["Sex"].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
x.replace({"Sex":{"male":1,"female":0}},inplace=True)

# %%
x.drop('Ticket',axis=1,inplace=True)

# %%
x
# Out:
#      PassengerId  Pclass  Sex   Age  SibSp  Parch     Fare Cabin Embarked
# 0              1       3    1  22.0      1      0   7.2500   C85        S
# 1              2       1    0  38.0      1      0  71.2833   C85        C
# 2              3       3    0  26.0      0      0   7.9250   C85        S
# 3              4       1    0  35.0      1      0  53.1000  C123        S
# 4              5       3    1  35.0      0      0   8.0500  C123        S
# ..           ...     ...  ...   ...    ...    ...      ...   ...      ...
# 886          887       2    1  27.0      0      0  13.0000   C50        S
# 887          888       1    0  19.0      0      0  30.0000   B42        S
# 888          889       3    0  22.5      1      2  23.4500   B42        S
# 889          890       1    1  26.0      0      0  30.0000  C148        C
# 890          891       3    1  32.0      0      0   7.7500  C148        Q
#
# [891 rows x 9 columns]

# %%
x.replace({'Cabin':'[A-Za-z]'},' ',regex=True,inplace=True)

# %%
x
# Out:
#      PassengerId  Pclass  Sex   Age  SibSp  Parch     Fare Cabin Embarked
# 0              1       3    1  22.0      1      0   7.2500    85        S
# 1              2       1    0  38.0      1      0  71.2833    85        C
# 2              3       3    0  26.0      0      0   7.9250    85        S
# 3              4       1    0  35.0      1      0  53.1000   123        S
# 4              5       3    1  35.0      0      0   8.0500   123        S
# ..           ...     ...  ...   ...    ...    ...      ...   ...      ...
# 886          887       2    1  27.0      0      0  13.0000    50        S
# 887          888       1    0  19.0      0      0  30.0000    42        S
# 888          889       3    0  22.5      1      2  23.4500    42        S
# 889          890       1    1  26.0      0      0  30.0000   148        C
# 890          891       3    1  32.0      0      0   7.7500   148        Q
#
# [891 rows x 9 columns]

# %%
x.drop('Cabin',axis=1,inplace=True)

# %%
x
# Out:
#      PassengerId  Pclass  Sex   Age  SibSp  Parch     Fare Embarked
# 0              1       3    1  22.0      1      0   7.2500        S
# 1              2       1    0  38.0      1      0  71.2833        C
# 2              3       3    0  26.0      0      0   7.9250        S
# 3              4       1    0  35.0      1      0  53.1000        S
# 4              5       3    1  35.0      0      0   8.0500        S
# ..           ...     ...  ...   ...    ...    ...      ...      ...
# 886          887       2    1  27.0      0      0  13.0000        S
# 887          888       1    0  19.0      0      0  30.0000        S
# 888          889       3    0  22.5      1      2  23.4500        S
# 889          890       1    1  26.0      0      0  30.0000        C
# 890          891       3    1  32.0      0      0   7.7500        Q
#
# [891 rows x 8 columns]

# %%
x["Embarked"].unique()
# Out:
# array(['S', 'C', 'Q'], dtype=object)

# %%
x.replace({"Embarked":{"S":1,"C":2,"Q":3}},inplace=True)

# %%
x.drop("PassengerId",axis=1,inplace=True)

# %%
x.dtypes
# Out:
# PassengerId      int64
# Pclass           int64
# Sex              int64
# Age            float64
# SibSp            int64
# Parch            int64
# Fare           float64
# Embarked         int64
# dtype: object

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25, random_state=42)

# %%
#creating the model
model=RandomForestClassifier()

#training the model
model.fit(x_train, y_train)

accuracy = model.score(x_test, y_test)
print(f"Model accuracy: {accuracy}")
# Out:
# Model accuracy: 0.8071748878923767
